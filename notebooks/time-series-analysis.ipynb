# %%
###Time Series Analysis

# %%
import pandas as pd
data = pd.read_csv("../data/fremont-bridge.csv", index_col= 'Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
data.columns = ["West", "East"]
data["Total"] = data["West"] + data["East"] 
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11120\1076815033.py in <module>
# ----> 1 data.columns = ["West", "East"]
#       2 data["Total"] = data["West"] + data["East"]
#       3 data.head()
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
#     770         self._clear_item_cache()
#     771
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     212     def set_axis(self, axis: int, new_labels: Index) -> None:
#     213         # Caller is responsible for ensuring we have an Index object.
# --> 214         self._validate_set_axis(axis, new_labels)
#     215         self.axes[axis] = new_labels
#     216
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\internals\base.py in _validate_set_axis(self, axis, new_labels)
#      67
#      68         elif new_len != old_len:
# ---> 69             raise ValueError(
#      70                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      71                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 2 elements

# %%
data.dropna().describe()
# Out:
#        Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# count          62030.000000                  62030.000000
# mean             114.654732                     52.859455
# std              145.686289                     67.739036
# min                0.000000                      0.000000
# 25%               15.000000                      7.000000
# 50%               62.000000                     29.000000
# 75%              150.000000                     71.000000
# max             1097.000000                    698.000000
#
#        Fremont Bridge West Sidewalk
# count                  62030.000000
# mean                      61.795276
# std                       90.417584
# min                        0.000000
# 25%                        7.000000
# 50%                       30.000000
# 75%                       74.000000
# max                      850.000000

# %%
import matplotlib.pyplot as plt
import seaborn
seaborn.set()
data.plot()
plt.ylabel("Hourly Bicycle count")
plt.show()

# %%
weekly = data.resample("W").sum()
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Weekly bicycle count')
plt.show()
